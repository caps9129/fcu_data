# %%
import pandas as pd
import datetime
import sys, traceback
import re
import matplotlib.pyplot as plt
import time,datetime
import numpy as np




plt.rcParams['font.sans-serif']=['DFKai-SB']
plt.rcParams['axes.unicode_minus']=False

df_list = []


arr_Student_Objects = []


file_name = "./newdata/new20170428-week-{}.csv"


def add_column():

    for read_index in range(1, 3):

        df = pd.read_csv(file_name.format(read_index))
        df.loc[-1] = df.columns.values
        df.index = df.index + 1  # shifting index
        df = df.sort_index()
        df.columns = ['time', 'mac', 'dep']
        df_list.append(df)

    df = pd.concat(df_list)
    df = df.reset_index(drop=True)
  
    return df

def groupby_loc(df):
    df_loc = df.groupby('dep')
    print(df_loc)  


def main():
    
    global df
    df = add_column()
    df.dropna()
    for index, row in df.iterrows():
        if(pd.isnull(row['dep'])):
            continue
        elif(row['dep'][:5].find("_") != -1): 
            row['dep'] = row['dep'][:2]
        else:
            row['dep'] = row['dep'][:5]

   
    

if __name__ == "__main__":
    main()
    print(df)
# Out:
#                         time                mac    dep
# 0        2017-04-27 23:59:58  94:65:9c:e4:29:65     ab
# 1        2017-04-27 23:59:58  94:65:9c:e4:29:65     ab
# 2        2017-04-27 23:59:57  a8:a7:95:a4:27:ed     bg
# 3        2017-04-27 23:59:56  f0:79:60:31:f4:84     bg
# 4        2017-04-27 23:59:56  f0:79:60:31:f4:84     bg
# 5        2017-04-27 23:59:55  b0:70:2d:f3:4a:7f     ab
# 6        2017-04-27 23:59:53  78:4f:43:7d:81:0c     ad
# 7        2017-04-27 23:59:53  78:4f:43:7d:81:0c     af
# 8        2017-04-27 23:59:53  b8:53:ac:1d:26:12     bg
# 9        2017-04-27 23:59:51  e4:a7:a0:1d:6f:f0     bg
# 10       2017-04-27 23:59:48  78:4f:43:7d:81:0c     af
# 11       2017-04-27 23:59:48  78:4f:43:7d:81:0c     ad
# 12       2017-04-27 23:59:46  60:a4:d0:42:97:2e     ad
# 13       2017-04-27 23:59:46  60:a4:d0:42:97:2e     ad
# 14       2017-04-27 23:59:45  70:3e:ac:39:31:71  gdorm
# 15       2017-04-27 23:59:45  70:3e:ac:39:31:71  bdorm
# ...

# %%
grouped = df.groupby(['mac', 'dep']).size().reset_index()
grouped.columns = ['mac', 'dep', 'aces']
grouped = grouped[(grouped.dep != 'gdorm') & (grouped.dep != 'bdorm') & (grouped.dep != 'ad') & (grouped.dep != 'be') & (grouped.dep != 'bg') & (grouped.dep != 'bh') & (grouped.dep != 'bi') & (grouped.dep != 'bj') & (grouped.dep != 'bk') & (grouped.dep != 'bn') & (grouped.dep != 'bw') & (grouped.dep != 'cb') & (grouped.dep != 'zk') & (grouped.dep != 'ab') & (grouped.dep != 'ac') & (grouped.dep != 'aa') & (grouped.dep != 'ba')]
grouped
# Out:
#                      mac dep  aces
# 4      00:02:d1:31:a9:04  bc     3
# 5      00:02:d1:31:a9:04  bd     9
# 8      00:08:22:24:44:51  ae     2
# 9      00:08:22:24:44:51  ah    33
# 11     00:08:22:24:44:51  bb     2
# 17     00:08:22:28:bf:9a  ah    12
# 18     00:08:22:28:bf:9a  bb     2
# 24     00:08:ca:28:24:3d  ae    15
# 25     00:08:ca:28:b7:b4  bm    28
# 27     00:08:ca:29:26:69  af     7
# 28     00:08:ca:29:26:69  bm     7
# 29     00:08:ca:39:0e:0b  bd     2
# 34     00:08:ca:67:13:96  ah     2
# 36     00:08:ca:69:18:a5  bd    80
# 38     00:08:ca:f0:47:2c  ae    27
# 39     00:08:ca:f1:da:d9  ae    47
# 40     00:08:ca:f3:b4:44  ah     5
# 43     00:08:ca:f4:1b:ce  ae    29
# 48     00:0a:f5:d5:f3:8c  ah    10
# 50     00:0a:f5:d5:f3:8c  bb     3
# 62     00:12:ee:57:3c:e0  ae    52
# 63     00:12:ee:57:3c:e0  af    22
# 67     00:15:af:34:a3:60  ae    66
# 69     00:15:af:34:ee:38  ae    89
# 71     00:15:af:be:af:6d  ah     3
# 74     00:15:af:e0:0f:42  ah    16
# ...

# %%
user = list()
real_user = list()
user = list(set(grouped['mac']))
user
# Out:
# ['f4:09:d8:eb:ea:34',
#  'd8:50:e6:96:76:ce',
#  '40:b8:37:15:d0:7e',
#  '5c:f7:e6:8e:b8:05',
#  '64:a5:c3:e8:15:98',
#  '58:40:4e:c7:b0:72',
#  '20:a2:e4:23:fe:dd',
#  '40:e2:30:1f:0c:cd',
#  '5c:e0:c5:2a:2c:3b',
#  '04:e6:76:a8:d9:85',
#  'e0:f8:47:1f:92:34',
#  'f0:03:8c:14:8a:49',
#  'a4:c3:61:02:ae:a0',
#  '0c:51:01:39:eb:db',
#  'ac:c1:ee:93:36:3f',
#  '38:b1:db:c7:39:ed',
#  '80:01:84:f7:6f:01',
#  'dc:85:de:14:fc:ea',
#  'e4:58:b8:0b:f6:3d',
#  '6c:8d:c1:4c:81:e2',
#  '30:75:12:f4:75:8c',
#  '18:5e:0f:89:bf:de',
#  '44:00:10:a0:27:2c',
#  '00:b3:62:13:70:d7',
#  '04:c2:3e:fd:25:e2',
#  'd4:0b:1a:88:57:54',
#  '84:7a:88:45:c8:76',
#  '6c:ab:31:79:b9:6c',
#  '58:48:22:f0:9f:32',
#  'e0:c7:67:dd:2f:81',
#  'a8:66:7f:95:36:ae',
#  '4c:21:d0:3e:45:d4',
#  '4c:57:ca:47:49:e7',
#  'c8:38:70:2d:8a:59',
#  '80:01:84:f7:69:47',
#  '1c:91:48:6d:ae:6a',
#  '58:48:22:78:0a:c0',
#  '9c:5c:f9:32:9a:18',
#  'ac:29:3a:e8:bb:a4',
#  'a4:d1:8c:24:14:38',
#  '08:62:66:63:c7:05',
# ...

# %%
list_loc = list()
list_del = list()
for user_index in range(len(user)):
    df_grouped = grouped[grouped['mac'] == user[user_index]].reset_index(drop=True)
    if(len(df_grouped) == 1):
        list_loc.append(df_grouped.loc[0].dep)
    else:   
        for df_grouped_index, row in df_grouped.iterrows():
            if(df_grouped_index == 0):
                sec_MAX = 0
                MAX = df_grouped.loc[df_grouped_index].aces
                MAX_index = df_grouped_index
            else:
                if(df_grouped.loc[df_grouped_index].aces > MAX):
                    MAX = df_grouped.loc[df_grouped_index].aces
                    MAX_index = df_grouped_index
                elif(df_grouped.loc[df_grouped_index].aces == MAX):
                    sec_MAX = df_grouped.loc[df_grouped_index].aces
                if(len(df_grouped) == df_grouped_index + 1):
                    if(sec_MAX == MAX):
                        list_del.append(user_index)
                    else:
                        list_loc.append(df_grouped.loc[MAX_index].dep)

# %%
len(list_loc)
# Out:
# 12094

# %%
real_user = user
for del_index in sorted(list_del, reverse=True):
    del real_user[del_index]
len(real_user)
# Out:
# 12094

# %%
real_user[:10]
# Out:
# ['f4:09:d8:eb:ea:34',
#  'd8:50:e6:96:76:ce',
#  '40:b8:37:15:d0:7e',
#  '5c:f7:e6:8e:b8:05',
#  '64:a5:c3:e8:15:98',
#  '58:40:4e:c7:b0:72',
#  '20:a2:e4:23:fe:dd',
#  '40:e2:30:1f:0c:cd',
#  '5c:e0:c5:2a:2c:3b',
#  '04:e6:76:a8:d9:85']

# %%
# plt(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
# percentile_list.plot(kind='line',figsize=(20,5))
plt.plot(list_loc[:50], real_user[:50], 'ro')

# plt.axis([0, 6, 0, 20])
# plt(figsize=(20, 5))
plt.show()

# %%
list_dep = list()
list_dep = list(set(list_loc))

list_dep

region_dict = {'行政一館':'aa', '忠勤樓':'ab', '語文大樓':'ac', '人言大樓':'ad', '理學院':'ae', '資訊電機館':'af',
               '商學院':'ah', '行政二館':'ba', '工學館':'bb', '建築館':'bc', '土水館':'bd', '圖書館':'be', '育樂館':'bg',
               '體育器材室':'bh', '紀念館':'bi', '科航館':'bj', '體育館':'bk', '電通館':'bm', '學思樓':'bn', '人社館':'bw',
               '男生宿舍':'bdorm', '文華創意中心':'cb', '女生宿舍':'gdorm', '中科校區':'zk'}
for index in range(len(list_dep)):
#     print(list(region_dict.keys())[list(region_dict.values()).index(list_ch_dep[index])])
    list_dep.append(list(region_dict.keys())[list(region_dict.values()).index(list_dep[index])]) 

list_dep

ch_length = len(list_dep)

# print(ch_length)
list_ch_dep = list_dep[int(ch_length / 2):int(ch_length + 1)]
list_eng_dep = list_dep[:int(ch_length / 2)]

list_eng_dep = ['bm', 'ah', 'bc', 'bd', 'af', 'bb', 'ae']
list_ch_dep = ['電通館', '商學院', '建築館', '土水館', '資訊電機館', '工學館', '理學院']

print(list_ch_dep)
list_eng_dep
# Out:
# ['電通館', '商學院', '建築館', '土水館', '資訊電機館', '工學館', '理學院']
# ['bm', 'ah', 'bc', 'bd', 'af', 'bb', 'ae']

# %%
list_count = list()
for list_eng_dep_index in range(len(list_eng_dep)):
    list_count.append(list_loc.count(list_eng_dep[list_eng_dep_index]))
list_count
# Out:
# [653, 3411, 612, 1361, 2725, 1616, 1716]

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(16, 10), dpi=120, facecolor='w', edgecolor='k')

plt.plot(list_ch_dep, list_count, linewidth=5.0)
# plt.plot(list_dep, list_count)
axes = plt.gca()
axes.set_ylim([0,4000])
plt.xlabel('學院類別')
plt.ylabel('人數')
plt.title('4/09、10、11、12、13_全校_WIFI使用者分群圖')
plt.grid(True)
plt.show()

# %%
df_ad = df[(df.dep == 'ad')]

df_ad = df_ad.groupby('mac').size().reset_index()

df_ad
# Out:
#                     mac    0
# 0     00:08:22:24:44:51    5
# 1     00:0a:f5:d5:f3:8c    2
# 2     00:0c:e7:c6:c5:bf    7
# 3     00:12:5f:09:3a:93  732
# 4     00:12:ee:57:3c:e0   14
# 5     00:18:60:71:03:5a    8
# 6     00:18:60:8a:86:0a   22
# 7     00:18:60:8e:3f:16    6
# 8     00:1b:77:d6:9c:24   11
# 9     00:1d:e0:6c:cd:f9    5
# 10    00:27:10:de:13:a0    3
# 11    00:27:15:11:00:22  176
# 12    00:27:15:de:aa:a8   70
# 13    00:34:da:09:f2:44   10
# 14    00:34:da:0f:fb:94    4
# 15    00:34:da:54:b8:36   33
# 16    00:34:da:55:6a:69   44
# 17    00:61:71:a0:65:42   16
# 18    00:6d:52:e7:67:67   37
# 19    00:71:cc:08:47:29    4
# 20    00:71:cc:3a:f7:91    9
# 21    00:71:cc:86:ac:3d    2
# 22    00:88:65:1d:2e:9d   32
# 23    00:88:65:3c:bd:fa   29
# 24    00:88:65:a6:06:3a    2
# 25    00:88:65:b5:92:07   11
# 26    00:9a:cd:da:20:15  450
# 27    00:9a:cd:dc:9c:a8   20
# 28    00:ae:fa:70:b4:dc    4
# 29    00:ae:fa:73:a0:8f   17
# ...                 ...  ...
# ...

# %%
list_ad = list()
for real_user_index in range(len(real_user)):
    for df_ad_index, row in df_ad.iterrows():
        if(df_ad.loc[df_ad_index].mac == real_user[real_user_index]):
            list_ad.append(list_loc[real_user_index])
            print(len(list_ad))
            continue
list_ad

# %%
list_ad_count = list()
for list_eng_dep_index in range(len(list_eng_dep)):
    list_ad_count.append(list_ad.count(list_eng_dep[list_eng_dep_index]))

list_ad_count

# list_eng_dep

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(16, 10), dpi=120, facecolor='w', edgecolor='k')

plt.plot(list_ch_dep, list_ad_count, linewidth=5.0)
# plt.plot(list_dep, list_count)
plt.xlabel('學院類別')
plt.ylabel('人數')
axes = plt.gca()
axes.set_ylim([0,4000])
plt.title('4/09、10、11、12、13_人言大樓_WIFI使用者分群圖')
plt.grid(True)
plt.show()
